# %%
import pandas as pd
import matplotlib.pyplot as plt

# Updated data based on the provided dataset
data = {
    'Set-1': {'A': 0.00061459, 'B': 0.00065041, 'C': 0.00056928, 'D': 0.00069107, 'E': 0.00054815, 'F': 0.00062508, 'G': 0.00060744,
              'H': 0.00069820, 'J': 0.00072522, 'K': 0.00074550, 'M': 0.00053093, 'N': 0.00062625},
    'Set-2': {'A': 0.00022093, 'B': 0.00017907, 'C': 0.00016388, 'D': 0.00016292, 'E': 0.00016312, 'F': 0.00013479, 'G': 0.00016101,
              'H': 0.00018895, 'J': 0.00016693, 'K': 0.00017765, 'M': 0.00015582, 'N': 0.00016977},
    'Set-3': {'A': 0.00045455, 'B': 0.00024217, 'C': 0.00024548, 'D': 0.00023810, 'E': 0.00039683, 'F': 0.00034050, 'G': 0.00004630,
              'H': 0.00028674, 'J': 0.00034858, 'K': 0.00020202, 'M': 0.00011905, 'N': 0.00029791},
    'Set-4': {'A': 0.00042982, 'B': 0.00045883, 'C': 0.00031611, 'D': 0.00046840, 'E': 0.00037906, 'F': 0.00034469, 'G': 0.00046535,
              'H': 0.00048554, 'J': 0.00043185, 'K': 0.00055455, 'M': 0.00035555, 'N': 0.00042692},
    'Set-5': {'A': 0.00034221, 'B': 0.00031146, 'C': 0.00031527, 'D': 0.00043887, 'E': 0.00036380, 'F': 0.00037892, 'G': 0.00031859,
              'H': 0.00034037, 'J': 0.00039319, 'K': 0.00037365, 'M': 0.00030440, 'N': 0.00030884},
    'Set-6': {'A': 0.00070595, 'B': 0.00067851, 'C': 0.00058324, 'D': 0.00073630, 'E': 0.00070445, 'F': 0.00067215, 'G': 0.00065237,
              'H': 0.00066450, 'J': 0.00066454, 'K': 0.00080177, 'M': 0.00060185, 'N': 0.00059300},
    'Set-7': {'A': 0.00081455, 'B': 0.00076855, 'C': 0.00069267, 'D': 0.00089895, 'E': 0.00076232, 'F': 0.00081808, 'G': 0.00076194,
              'H': 0.00075218, 'J': 0.00081162, 'K': 0.00079091, 'M': 0.00082353, 'N': 0.00076550},
    'Set-8': {'A': 0.00085714, 'B': 0.00085714, 'C': 0.00085714, 'D': 0.00085714, 'E': 0.00085714, 'F': 0.00085714, 'G': 0.00085714,
              'H': 0.00085714, 'J': 0.00085714, 'K': 0.00085714, 'M': 0.00085714, 'N': 0.00085714},
    'Set-9': {'A': 0.00169312, 'B': 0.00169312, 'C': 0.00169312, 'D': 0.00169312, 'E': 0.00169312, 'F': 0.00169312, 'G': 0.00169312,
              'H': 0.00169312, 'J': 0.00169312, 'K': 0.00169312, 'M': 0.00169312, 'N': 0.00169312}
}

# Convert the data to a DataFrame, filling missing values with NaN
df = pd.DataFrame(data)

# Calculate the average for each row (metal type), ignoring NaNs
averages = df.mean(axis=1)

# Print the average values with more decimal points
for metal, avg in averages.items():
    print(f"{metal}: {avg:.5f}")

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(averages, marker='o', linestyle='-', color='lightblue')
for i, (metal, value) in enumerate(averages.items()):
    plt.text(i, value, f"{value:.8f}", ha='center', va='bottom')
plt.xlabel('Metal Type')
plt.ylabel('Average Concentration Drop')
plt.title('Average Concentration Drop for each Metal Type')
plt.grid(True)
plt.show()
# Out:
# A: 0.00068
# B: 0.00065
# C: 0.00060
# D: 0.00069
# E: 0.00065
# F: 0.00065
# G: 0.00062
# H: 0.00066
# J: 0.00068
# K: 0.00069
# M: 0.00060
# N: 0.00064
